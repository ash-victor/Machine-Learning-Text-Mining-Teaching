# %% [markdown]
# <a href="https://colab.research.google.com/github/ash-victor/Text-Mining-Teaching/blob/main/Ashley_Victor_Medical_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install neattext
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.7/114.7 kB 2.8 MB/s eta 0:00:00
# ...

# %%
## Load python packages
import pandas as pd # Create our dataframe
import numpy as np

# Load data viz packages
import matplotlib.pyplot as plt
import seaborn as sns

# Text cleaning
import neattext.functions as nfx

# %%
# Load Dataset
data = pd.read_csv("mtsamples.csv")

# %%
# Preview the Data
#print(data)
data.head(10)
# Out:
#    Unnamed: 0                                        description  \
# 0           0   A 23-year-old white female presents with comp...
# 1           1           Consult for laparoscopic gastric bypass.
# 2           2           Consult for laparoscopic gastric bypass.
# 3           3                             2-D M-Mode. Doppler.
# 4           4                                 2-D Echocardiogram
# 5           5   Morbid obesity.  Laparoscopic antecolic anteg...
# 6           6   Liposuction of the supraumbilical abdomen, re...
# 7           7                                 2-D Echocardiogram
# 8           8   Suction-assisted lipectomy - lipodystrophy of...
# 9           9                         Echocardiogram and Doppler
#
#              medical_specialty                                sample_name  \
# 0         Allergy / Immunology                         Allergic Rhinitis
# 1                   Bariatrics   Laparoscopic Gastric Bypass Consult - 2
# ...

# %%
# Shape: how many columns and rows
data.shape
# Out:
# (4999, 6)

# %%
# Datatypes
data.dtypes
# Out:
# Unnamed: 0            int64
# description          object
# medical_specialty    object
# sample_name          object
# transcription        object
# keywords             object
# dtype: object

# %%
# Check for missing values
data.isnull().sum()
# Out:
# Unnamed: 0              0
# description             0
# medical_specialty       0
# sample_name             0
# transcription          33
# keywords             1068
# dtype: int64

# %%
#
data['medical_specialty'].value_counts()
# Out:
#  Surgery                          1103
#  Consult - History and Phy.        516
#  Cardiovascular / Pulmonary        372
#  Orthopedic                        355
#  Radiology                         273
#  General Medicine                  259
#  Gastroenterology                  230
#  Neurology                         223
#  SOAP / Chart / Progress Notes     166
#  Obstetrics / Gynecology           160
#  Urology                           158
#  Discharge Summary                 108
#  ENT - Otolaryngology               98
#  Neurosurgery                       94
#  Hematology - Oncology              90
#  Ophthalmology                      83
#  Nephrology                         81
#  Emergency Room Reports             75
#  Pediatrics - Neonatal              70
#  Pain Management                    62
#  Psychiatry / Psychology            53
#  Office Notes                       51
#  Podiatry                           47
#  Dermatology                        29
# ...

# %%
data['medical_specialty'].value_counts().plot(kind='bar')
plt.title('Distribution of Medical Specialties')
# Out:
# Text(0.5, 1.0, 'Distribution of Medical Specialties')

# %%
sns.countplot(x ='medical_specialty', data = data)
plt.xticks(rotation=90)
plt.title('Distribution of Medical Specialties')
# Out:
# Text(0.5, 1.0, 'Distribution of Medical Specialties')
